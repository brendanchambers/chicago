# %%
import geopandas as gp
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import json

# scraping
from bs4 import BeautifulSoup
import urllib.request

# scale figures
scale_factor = 2
default_dpi = mpl.rcParamsDefault['figure.dpi']
mpl.rcParams['figure.dpi'] = default_dpi*8

# %%
data_path = 'data/cook county commissioners/geo_export_0cef89ff-ad64-4d89-aed0-249c58407c73.shp'
shapes = gp.GeoDataFrame.from_file(data_path)

print(shapes.head())
# Out:
#   district lastname                                         location_2  \
# 0      1st   Boykin                7221 Madison\nForest Park, IL 60130
# 1      2nd     Deer  3936 W Roosevelt Road\nChicago, IL 60624\n(41....
# 2      3rd   Butler  118 N Clark St\nChicago, IL 60602\n(41.8838502...
# 3      4th    Moore  8658 S Cottage Grove, Suite 404\nChicago, IL 6...
# 4      5th     Sims  2515 Veterans Dr\nPosen, IL 60469\n(41.6256410...
#
#      shape_area                               url2 _socrataid middlename  \
# 0  8.066350e+08                               None  mta9-scxc         R.
# 1  6.944401e+08                               None  qfcq-csa6       None
# 2  6.118677e+08                               None  jb95-ck3i       None
# 3  1.609208e+09  http://www.commissionermoore.com/  dfrx-xxkw       None
# 4  2.137764e+09                               None  43kp-7gnn       None
#
#   email2 firstname                                               url1  \
# 0   None   Richard  https://www.cookcountyil.gov/person/richard-bo...
# 1   None    Dennis    https://www.cookcountyil.gov/person/dennis-deer
# 2   None     Jerry   https://www.cookcountyil.gov/person/jerry-butler
# 3   None   Stanley  https://www.cookcountyil.gov/person/stanley-moore
# 4   None   Deborah  https://www.cookcountyil.gov/person/deborah-si...
#
#            phone2                                         location_1  \
# 0            None  118 N Clark St\nChicago, IL 60602\n(41.8838502...
# 1  (773) 722-0140  118 N Clark St\nChicago, IL 60602\n(41.8838502...
# 2            None  118 N Clark St\nChicago, IL 60602\n(41.8838502...
# 3  (773) 783-2412  118 N Clark St\nChicago, IL 60602\n(41.8838502...
# 4  (708) 371-4251  118 N Clark St\nChicago, IL 60602\n(41.8838502...
#
#                             email1      shape_len          phone1  \
# 0  richard.boykin@cookcountyil.gov  209248.414370  (312) 603-4566
# 1     Dennis.Deer@cookcountyil.gov  269708.207752  (312) 603-3019
# 2    jerry.butler@cookcountyil.gov  317622.111681  (312) 603-6391
# 3  Stanley.moore2@cookcountyil.gov  327262.369610  (312) 603-2065
# 4    deborah.sims@cookcountyil.gov  415172.894535  (312) 603-6381
#
#                                             geometry
# 0  POLYGON ((-87.78612500037407 41.93996999936652...
# 1  POLYGON ((-87.65861199999257 41.89632599900312...
# 2  POLYGON ((-87.6443740003231 41.91156599923575,...
# 3  POLYGON ((-87.56009799955577 41.7663389989488,...
# 4  POLYGON ((-87.63703799955249 41.7175429989971,...

# %%
plt.figure()
ax = plt.gca()

for idx in range(shapes.shape[0]):
    
    district_id = shapes.loc[idx,'district']
    try:
        plot_color = 'white'
        shapes.loc[[idx],'geometry'].plot(ax=ax, alpha=0.6, linewidth=0.5, edgecolor='black',facecolor=plot_color)
        
    except Exception as e: # no data
        print('warning...')
        print(e)
        
        plot_color='gray' 
        shapes.loc[[idx],'geometry'].plot(ax=ax, alpha=0.6, linewidth=0.5, edgecolor='black',facecolor=plot_color)

plt.axis('scaled')
plt.axis('off')
plt.savefig("chicago_wards.svg")
plt.show()
